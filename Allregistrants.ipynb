# %%
# import pandas
import pandas as pd

# %%
# import seaborn library
import seaborn as sns
sns.set_style("whitegrid")

# %%
# import matplotlib library
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Try exception error
try:
    df = pd.read_csv("AllRegistrantsToUpendra_20190219.csv", encoding = "ISO-8859-1")
except UnicodeDecodeError as error:
    print("UnicodeDEcodeErorr")
except FileNotFoundError as fnf_error:
    print("File not found")

# %%
# First two rows of the dataframe
df.head(2)
# Out:
#       Timestamp    Accepted Confirmed  \
# 0  2/15/19 9:26  20190218.0         1
# 1  2/6/19 15:50  20190218.0         1
#
#   Occupational status (check the most relevant in the context of the workshop)  \
# 0                                            Faculty
# 1                                   Graduate Student
#
#   What organization(s) do you work for? What department(s) do you work in?  \
# 0                                BUMC-T                  Internal Medicine
# 1                 University of Arizona                          Sociology
#
#   In three sentences or less, please describe your current field of work or research question.  \
# 0  Infectious Diseases in the Immunocompromised p...
# 1              political violence, collective memory
#
#   How do you intend to make use of what you will learn in the workshop? What do you hope the workshop will help you with?  \
# 0  More efficient data analysis and methods to ex...
# 1                                           research
#
#   What operating system will you use on the laptop you bring to the workshop?  \
# 0                                                Mac
# 1                                            Windows
#
#   Waiver 1 Waiver 2 SWD?  \
# 0  I agree  I agree   No
# 1  I agree  I agree   No
#
#   What best describes how you currently manage your data/projects? (Check all that apply.)  \
# 0                   My data reside on my hard drive.
# 1                   My data reside on my hard drive.
#
#   What best describes how you currently analyze your data? (Check all that apply.)  \
# 0  I am analyzing my data by looking at them and ...
# 1  I am analyzing my data with an office software...
#
#   What best describes how frequently you currently program?  \
# 0                     I program several times a year
# 1                     I program several times a year
#
#   What best describes the complexity of your programming? (Check all that apply.)  \
# 0  I write scripts that are a few lines long to a...
# 1  I write scripts that are a few lines long to a...
#
#   How familiar are you with Bash? (a.k.a. Unix, Command line, Shell) Please select the answer that best applies to you:  \
# 0           I am not familiar with the command line.
# 1  I am familiar with the command line but have n...
#
#   How would you solve this task: A directory contains 1000 text files. Create a list of all files that contain the word "Drosophila" and save the result to a file called results.txt.  \
# 0  I could complete the task with documentation o...
# 1  I could complete the task with documentation o...
#
#   How familiar are you with version control? Please select the answer that best applies to you:  \
# 0            I am not familiar with version control.
# 1                  I am familiar only with the term.
#
#   How would you solve this task: Given the URL for a project's version control repository, check out a working copy of that project, add a file called notes.txt, and commit the change.  \
# 0  I could complete the task with documentation o...
# 1  I could complete the task with documentation o...
#
#   How familiar are you with Python/Jupyter Notebook? Please select the answer that best applies to you:  \
# 0  I am familiar with Python because I have used ...
# 1  I am familiar with Python because I have used ...
#
#   How would you solve this task: A tab-delimited file has two columns showing for the last four decades the date for each day and the highest temperature on that day. Design a program to produce a graph for these data showing the average highest temperature for each month.  \
# 0  I could complete the task with documentation o...
# 1  I could complete the task with documentation o...
#
#   Please check which of the following you would be interested in a future workshop. (Your response will have no bearing on your chance to be accepted to the workshop.)
# 0  High Performance Computing using the UA HPC sy...
# 1  Quality assurance (to ensure my code does what...

# %%
# Shape of the dataframe
df.shape
# Out:
# (76, 23)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Accepted', 'Confirmed',
#        'Occupational status (check the most relevant in the context of the workshop)',
#        'What organization(s) do you work for?',
#        'What department(s) do you work in?',
#        'In three sentences or less, please describe your current field of work or research question.',
#        'How do you intend to make use of what you will learn in the workshop? What do you hope the workshop will help you with?',
#        'What operating system will you use on the laptop you bring to the workshop?',
#        'Waiver 1', 'Waiver 2', 'SWD?',
#        'What best describes how you currently manage your data/projects? (Check all that apply.)',
#        'What best describes how you currently analyze your data? (Check all that apply.)',
#        'What best describes how frequently you currently program?',
#        'What best describes the complexity of your programming? (Check all that apply.)',
#        'How familiar are you with Bash? (a.k.a. Unix, Command line, Shell) Please select the answer that best applies to you:',
#        'How would you solve this task: A directory contains 1000 text files. Create a list of all files that contain the word "Drosophila" and save the result to a file called results.txt.',
#        'How familiar are you with version control? Please select the answer that best applies to you:',
#        'How would you solve this task: Given the URL for a project's version control repository, check out a working copy of that project, add a file called notes.txt, and commit the change.',
#        'How familiar are you with Python/Jupyter Notebook? Please select the answer that best applies to you:',
#        'How would you solve this task: A tab-delimited file has two columns showing for the last four decades the date for each day and the highest temperature on that day. Design a program to produce a graph for these data showing the average highest temperature for each month.',
#        'Please check which of the following you would be interested in a future workshop. (Your response will have no bearing on your chance to be accepted to the workshop.)'],
#       dtype='object')

# %%
df.drop(['Timestamp', 'Waiver 1', 'Waiver 2', 'SWD?'], axis = 1, inplace=True)

# %%
old_columns = list(df.columns)
old_columns, len(old_columns)
# Out:
# (['Accepted',
#   'Confirmed',
#   'Occupational status (check the most relevant in the context of the workshop)',
#   'What organization(s) do you work for?',
#   'What department(s) do you work in?',
#   'In three sentences or less, please describe your current field of work or research question.',
#   'How do you intend to make use of what you will learn in the workshop? What do you hope the workshop will help you with?',
#   'What operating system will you use on the laptop you bring to the workshop?',
#   'What best describes how you currently manage your data/projects? (Check all that apply.)',
#   'What best describes how you currently analyze your data? (Check all that apply.)',
#   'What best describes how frequently you currently program?',
#   'What best describes the complexity of your programming? (Check all that apply.)',
#   'How familiar are you with Bash? (a.k.a. Unix, Command line, Shell) Please select the answer that best applies to you:',
#   'How would you solve this task: A directory contains 1000 text files. Create a list of all files that contain the word "Drosophila" and save the result to a file called results.txt.',
#   'How familiar are you with version control? Please select the answer that best applies to you:',
#   "How would you solve this task: Given the URL for a project's version control repository, check out a working copy of that project, add a file called notes.txt, and commit the change.",
#   'How familiar are you with Python/Jupyter Notebook? Please select the answer that best applies to you:',
#   'How would you solve this task: A tab-delimited file has two columns showing for the last four decades the date for each day and the highest temperature on that day. Design a program to produce a graph for these data showing the average highest temperature for each month.',
#   'Please check which of the following you would be interested in a future workshop. (Your response will have no bearing on your chance to be accepted to the workshop.)'],
#  19)

# %%
new_columns = ['Accepted', 'Confirmed', 'Occupation', 'Organization', 'Department', 'Research', 'Reason', 'OS', 'Manage_data', \
           'Analyze_data', 'Frequency', 'Complexity', 'Bash', 'Directory_task', 'Version_control', 'Version_control_task',\
          'Python_Jupyter', 'Program_task', 'Future_workshop']
new_columns, len(columns)
# Out:
# (['Accepted',
#   'Confirmed',
#   'Occupation',
#   'Organization',
#   'Department',
#   'Research',
#   'Reason',
#   'OS',
#   'Manage_data',
#   'Analyze_data',
#   'Frequency',
#   'Complexity',
#   'Bash',
#   'Directory_task',
#   'Version_control',
#   'Version_control_task',
#   'Python_Jupyter',
#   'Program_task',
#   'Future_workshop'],
#  19)

# %%
col_rename_dict = {i:j for i, j in zip(old_columns, new_columns)}
df_new = df.rename(columns=col_rename_dict)

# %%
df_new.head(2)
# Out:
#      Accepted Confirmed        Occupation           Organization  \
# 0  20190218.0         1           Faculty                 BUMC-T
# 1  20190218.0         1  Graduate Student  University of Arizona
#
#           Department                                           Research  \
# 0  Internal Medicine  Infectious Diseases in the Immunocompromised p...
# 1          Sociology              political violence, collective memory
#
#                                               Reason       OS  \
# 0  More efficient data analysis and methods to ex...      Mac
# 1                                           research  Windows
#
#                         Manage_data  \
# 0  My data reside on my hard drive.
# 1  My data reside on my hard drive.
#
#                                         Analyze_data  \
# 0  I am analyzing my data by looking at them and ...
# 1  I am analyzing my data with an office software...
#
#                         Frequency  \
# 0  I program several times a year
# 1  I program several times a year
#
#                                           Complexity  \
# 0  I write scripts that are a few lines long to a...
# 1  I write scripts that are a few lines long to a...
#
#                                                 Bash  \
# 0           I am not familiar with the command line.
# 1  I am familiar with the command line but have n...
#
#                                       Directory_task  \
# 0  I could complete the task with documentation o...
# 1  I could complete the task with documentation o...
#
#                            Version_control  \
# 0  I am not familiar with version control.
# 1        I am familiar only with the term.
#
#                                 Version_control_task  \
# 0  I could complete the task with documentation o...
# 1  I could complete the task with documentation o...
#
#                                       Python_Jupyter  \
# 0  I am familiar with Python because I have used ...
# 1  I am familiar with Python because I have used ...
#
#                                         Program_task  \
# 0  I could complete the task with documentation o...
# 1  I could complete the task with documentation o...
#
#                                      Future_workshop
# 0  High Performance Computing using the UA HPC sy...
# 1  Quality assurance (to ensure my code does what...

# %%
ax, fig = plt.subplots(1,1, figsize = (10, 15))
sns.countplot(y = "Department", 
              data=df_new,
              order=df_new["Department"].value_counts(ascending=True).index);
plt.xticks(rotation=90);

# %%
df_new.OS.unique()
# Out:
# array(['Mac', 'Windows', 'I am not sure', 'Windows and Mac', 'Linux',
#        'Chromebook running Linux and CyVerse VICE, but I can bring a Linux laptop instead.',
#        'Windows 10 (host), Ubuntu 18 (VirtualBox)'], dtype=object)

# %%
ax, fig = plt.subplots(1,1, figsize = (5,5))
sns.countplot(x = "OS",
             data = df_new);
plt.xticks(rotation = 90);

# %%
df_new.OS.replace('Chromebook running Linux and CyVerse VICE, but I can bring a Linux laptop instead.', 'Linux', inplace=True)
df_new.OS.replace('Windows 10 (host), Ubuntu 18 (VirtualBox)', 'Linux', inplace=True)

# %%
ax, fig = plt.subplots(1,1, figsize = (5,5))
sns.countplot(x = "OS",
             data = df_new,
             order=df_new["OS"].value_counts(ascending=False).index);
plt.xticks(rotation = 90);
plt.xlabel("Operating System");

# %% [markdown]
# ### Occupation

# %%
ax, fig = plt.subplots(1,1, figsize = (5,5))
sns.countplot(y = "Occupation",
             data = df_new,
             order=df_new["Occupation"].value_counts(ascending=False).index);
plt.xticks(rotation = 90);
plt.xlabel("Occupation");

# %% [markdown]
# ### Research

# %%
# Import libraries
from wordcloud import WordCloud

# Create a list of word
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")

# Create the wordcloud object
wc = WordCloud(width=960, height=960, margin=0).generate(text)
 
# Display the generated image:
plt.imshow(wc, interpolation='bilinear');
plt.axis("off");
plt.margins(x=0, y=0);

# %%
from io import StringIO

# %%
si = StringIO()
df_new["Research"].apply(lambda x: si.write(str(x)))
s = si.getvalue()
si.close()
# Out:
# 0      55
# 1      37
# 2      68
# 3     225
# 4      96
# 5      43
# 6      30
# 7      44
# 8      67
# 9     301
#      ...
# 66    174
# 67     18
# 68    142
# 69     63
# 70     19
# 71     14
# 72    134
# 73    383
# 74    298
# 75    346
# Name: Research, Length: 76, dtype: int64

# %%
# Read the whole text.
text = s

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(background_color="white",max_words=len(s),max_font_size=40, relative_scaling=.5).generate(text)
plt.figure();
plt.imshow(wordcloud);
plt.axis("off");
